# %%
print("ok")
# Out:
# ok

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("hi")
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 36, 'total_tokens': 59, 'completion_time': 0.041793126, 'completion_tokens_details': None, 'prompt_time': 0.003470494, 'prompt_tokens_details': None, 'queue_time': 0.048814896, 'total_time': 0.04526362}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c2cc7-983d-7922-8f91-a5c9ce4e2feb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 23, 'total_tokens': 59})

# %%
from langchain.tools import tool

# %%
@tool
def multiply(a: int,b: int) -> int:
    """Multiply two integers and return the result."""
    return a*b

# %%
multiply
# Out:
# StructuredTool(name='multiply', description='Multiply two integers and return the result.', args_schema=<class 'langchain_core.utils.pydantic.multiply'>, func=<function multiply at 0x0000022B7716B6A0>)

# %%
from langchain_core.tools import StructuredTool

# %%
from pydantic import BaseModel

# %%
class WeatherInput(BaseModel):
    city: str

# %%
def get_weather(city: str) -> str:
    """
    Get the weather for a given city.

    Args:
        city (str): The name of the city.

    Returns:
        str: A string describing the weather in the city.
    """
    return f"The weather in {city} is sunny."

# %%
weather_tool = StructuredTool.from_function(
    func=get_weather,
    name="get_weather",
    description="Fetches real-time weather data for a city",
    args_schema=WeatherInput,
)

# %%
class WeatherInput(BaseModel):
    city: str = Field(..., description="City name")
    units: str = Field("metric", description="metric or imperial")

class GetWeatherTool(StructuredTool):
    name: ClassVar[str] = "get_weather"           
    description: ClassVar[str] = (
        "Fetches weather data for a city"
    )
    args_schema: ClassVar[Type[BaseModel]] = WeatherInput

    def _run(self, city: str, units: str = "metric") -> str:
        return get_weather(city, units)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 class WeatherInput(BaseModel):
#       2     city: str = Field(..., description="City name")
#       3     units: str = Field("metric", description="metric or imperial")
#
# Cell In[21], line 2, in WeatherInput()
#       1 class WeatherInput(BaseModel):
# ----> 2     city: str = Field(..., description="City name")
#       3     units: str = Field("metric", description="metric or imperial")
#
# NameError: name 'Field' is not defined
